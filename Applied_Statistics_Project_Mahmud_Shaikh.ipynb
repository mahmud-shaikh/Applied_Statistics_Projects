# %% [markdown]
# <a href="https://colab.research.google.com/github/mahmud-shaikh/Applied_Statistics_Projects/blob/main/Applied_Statistics_Project_Mahmud_Shaikh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**  -**Customer Purchase Behavior Analysis using Descriptive Statistics**

# %% [markdown]
# ##### **Project Type**    - Analysis using Descriptive Statistics
# ##### **Contribution**    - Individual
# ##### **Team Member 1 - Mahmud Shaikh**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project aimed to understand customer purchasing behavior using a dataset containing demographic information and spending patterns. We explored relationships between factors like income, age, and purchase frequency across different product categories.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ##Task 1 - Basic CleanUp

# %% [markdown]
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
data=pd.read_csv('/content/Superstore Marketing Data.csv')

# %% [markdown]
# ###Dataset First View

# %%
#Data set first view
df=data.copy()
df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset rows and columns count
df.shape
# Out:
# (2240, 22)

# %% [markdown]
# ### Dataset information

# %%
# Dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %% [markdown]
# ### Duplicate values

# %%
#Dataset duplicate value count
duplicate_count=df.duplicated().sum()
print(duplicate_count)
# Out:
# 0

# %% [markdown]
# ### Missing values/Null Values

# %%
#Missing/Null values
df.isnull().sum()
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# dtype: int64

# %%
# There are 24 null values on column income,using the mean imputations, fill the values in this column.
mean_income = df['Income'].mean()
df['Income']=df['Income'].fillna(mean_income)

# %%
# Check wether missing values filled or not
print(df['Income'].isnull().sum())
# Out:
# 0

# %%
# Replace "########" with NaN in the "Dt_Customer" column
df['Dt_Customer'] = df['Dt_Customer'].replace('########', pd.NA)

# %%
# Check rows with missing values in the "Dt_Customer" column
print(df['Dt_Customer'].isnull().sum())
# Out:
# 916

# %%
# Remove rows with missing values in the "Dt_Customer" column
df = df.dropna(subset=['Dt_Customer'])

# %%
# Check wether missing values removed or not
print(df['Dt_Customer'].isnull().sum())
# Out:
# 0

# %%
# Convert 'Dt_Customer' column to datetime object
df.loc['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'])
# Out:
# <ipython-input-69-95c2052f8a56>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'])

# %%
df['Year_Birth'] = pd.to_numeric(df['Year_Birth'], errors='coerce').astype('Int64')
df = df.dropna(subset=['Year_Birth'])
# Out:
# <ipython-input-70-18661b0b111a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year_Birth'] = pd.to_numeric(df['Year_Birth'], errors='coerce').astype('Int64')

# %%
# To calculate age from the year of 1996, because we have maximum year as 1996 in dataset.
df['Age'] = 1996 - df['Year_Birth']

# %%
df['Age'].sort_values()
# Out:
# 1824      0
# 1298      1
# 1467      1
# 1468      1
# 259       2
#        ...
# 1644     53
# 1740     55
# 2233     96
# 827      97
# 513     103
# Name: Age, Length: 1324, dtype: Int64

# %%
# To show age is greater than 100
df[df['Age']>100]
# Out:
#         Id  Year_Birth Education Marital_Status   Income Kidhome Teenhome  \
# 513  11004        1893  2n Cycle         Single  60182.0       0        1
#
#     Dt_Customer Recency MntWines  ... MntSweetProducts MntGoldProds  \
# 513   5/17/2014      23        8  ...                0            2
#
#     NumDealsPurchases NumWebPurchases NumCatalogPurchases NumStorePurchases  \
# 513                 1               1                   0                 2
#
#     NumWebVisitsMonth Response Complain  Age
# 513                 4        0        0  103
#
# [1 rows x 23 columns]

# %%
# Remove age which are greater than 100
df.drop(df[df['Age']>100].index, inplace=True)

# %%
# Check wether age >100 removed or not.
df[df['Age']>100]
# Out:
# Empty DataFrame
# Columns: [Id, Year_Birth, Education, Marital_Status, Income, Kidhome, Teenhome, Dt_Customer, Recency, MntWines, MntFruits, MntMeatProducts, MntFishProducts, MntSweetProducts, MntGoldProds, NumDealsPurchases, NumWebPurchases, NumCatalogPurchases, NumStorePurchases, NumWebVisitsMonth, Response, Complain, Age]
# Index: []
#
# [0 rows x 23 columns]

# %%
df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income Kidhome Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0       0        0
# 1      1        1961  Graduation         Single  57091.0       0        0
# 2  10476        1958  Graduation        Married  67267.0       0        1
# 5   7348        1958         PhD         Single  71691.0       0        0
# 6   4073        1954    2n Cycle        Married  63564.0       0        0
#
#   Dt_Customer Recency MntWines  ... MntSweetProducts MntGoldProds  \
# 0   6/16/2014       0      189  ...              189          218
# 1   6/15/2014       0      464  ...                0           37
# 2   5/13/2014       0      134  ...                2           30
# 5   3/17/2014       0      336  ...               32           43
# 6   1/29/2014       0      769  ...               34           65
#
#   NumDealsPurchases NumWebPurchases NumCatalogPurchases NumStorePurchases  \
# ...

# %%
# Calculate descriptive statistics
demographics_stats = df[['Age', 'Education', 'Marital_Status']].describe(include='all')

print("Descriptive Statistics for Demographics:")
print(demographics_stats)
# Out:
# Descriptive Statistics for Demographics:
#               Age   Education Marital_Status
# count      1323.0        1323           1323
# unique       <NA>           5              8
# top          <NA>  Graduation        Married
# freq         <NA>         686            505
# mean    27.257748         NaN            NaN
# std     11.930114         NaN            NaN
# min           0.0         NaN            NaN
# 25%          19.0         NaN            NaN
# 50%          26.0         NaN            NaN
# 75%          37.0         NaN            NaN
# max          97.0         NaN            NaN

# %%
# To replace '2nd cycle' with the 'Graduation' in the column of Education
df['Education'] = df['Education'].replace('2n Cycle', 'Graduation')

# %%
# Replacing 'YOLO', 'Alone', 'Absurd' with 'Single' and 'Together' with 'Married'
df["Marital_Status"] = df["Marital_Status"].replace(["YOLO", "Alone", "Absurd"], "Single")
df["Marital_Status"] = df["Marital_Status"].replace(["Together"], "Married")

# %%
# Calculate value counts for each category
education_counts = df['Education'].value_counts()
marital_counts = df['Marital_Status'].value_counts()

# Calculate proportions if needed
education_proportions = df['Education'].value_counts(normalize=True)
marital_proportions = df['Marital_Status'].value_counts(normalize=True)

print("Education Counts:")
print(education_counts)
print("\nMarital Status Counts:")
print(marital_counts)
# Out:
# Education Counts:
# Education
# Graduation    790
# PhD           273
# Master        224
# Basic          36
# Name: count, dtype: int64
#
# Marital Status Counts:
# Marital_Status
# Married     848
# Single      288
# Divorced    151
# Widow        36
# Name: count, dtype: int64

# %% [markdown]
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %%
# Visualizing Age distribution
plt.figure(figsize=(6, 4))
sns.histplot(data=df, x='Age', bins=20, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Insights**: The age group between 20 to 40 has the maximum number of frequency count. It means that, it has maximum marketing data.

# %%
# Visualizing education distribution
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Education',hue='Education', palette='Set1', legend=False)
plt.title('Education Distribution')
plt.xlabel('Education Level')
plt.ylabel('Count')
# plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Insights:** The Graduation holder has the maximum number of count with respect to others education level and PhD holder is in the 2nd position.

# %%
# Visualizing marital status distribution
plt.figure(figsize=(5, 4))
ax=sns.countplot(data=df, x='Marital_Status',hue='Marital_Status', palette='Set1', legend=False)
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}',
                (p.get_x() + p.get_width() / 2., height),
                ha='center', va='bottom', fontsize=10)
plt.title('Marital Status Distribution')
plt.xlabel('Marital Status')
plt.ylabel('Count')
# plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Insights:** There are 848 people who got married and 288 people who are unmarried(single), about 151 who are divorced, and 36 who are widows.

# %% [markdown]
# ##Task 2 - Descriptive Statistics 📊
#
# - **Calculate measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %% [markdown]
# Lets identifiy the key variables depends on the context of the analysis or the specific research question.It contains Numeric, Categorical, Ordinal and Time-Series Variables.

# %%
# Numeric Variables: Variables that consist of numerical values such as age, income etc.
# Calculating mean, median, mode for each key variable.

central_tendency = df[['Age', 'Income']].agg(['mean', 'median', lambda x: x.mode().iloc[0]])
central_tendency.index=['Mean', 'Median', 'Mode']
central_tendency
# Out:
#               Age        Income
# Mean    27.257748  51431.164979
# Median  26.000000  50664.000000
# Mode    25.000000  52247.251354

# %%
# Calculating variance and standard deviation for each key variable
dispersion = df[['Age', 'Income']].agg(['var', 'std'])
dispersion
# Out:
#             Age        Income
# var  142.327616  4.352902e+08
# std   11.930114  2.086361e+04

# %%
#Converting Income to numerical data type
df['Income']=pd.to_numeric(df['Income'])

# %%
from scipy.stats import zscore

# Calculating z-scores for each key variable
z_scores = df[['Age', 'Income']].apply(zscore)

# Threshold for considering outliers
threshold = 3

# Identifying and handling outliers for each key variable
outliers = (np.abs(z_scores) > threshold)

# Re-calculating central tendency and dispersion after handling outliers
central_tendency_without_outliers = df[['Age', 'Income']].agg(['mean', 'median', lambda x: x.mode().iloc[0]])
dispersion_without_outliers = df[['Age', 'Income']].agg(['var', 'std'])

print("\nMeasures of Central Tendency (without outliers):")
print(central_tendency_without_outliers)
print("\nMeasures of Dispersion (without outliers):")
print(dispersion_without_outliers)
# Out:
# Measures of Central Tendency (without outliers):
#                 Age        Income
# mean      27.257748  51431.164979
# median    26.000000  50664.000000
# <lambda>  25.000000  52247.251354
#
# Measures of Dispersion (without outliers):
#             Age        Income
# var  142.327616  4.352902e+08
# std   11.930114  2.086361e+04

# %%
df["Total_Amount_Spent"] = df[
    [
        "MntWines",
        "MntFruits",
        "MntMeatProducts",
        "MntFishProducts",
        "MntSweetProducts",
        "MntGoldProds",
    ]
].sum(axis=1)

# %%
def histogram_boxplot(data, feature, figsize=(10, 4), kde=False, bins=None):

    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a triangle will indicate the mean value of the column
    sns.histplot(data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
def stacked_barplot(data, predictor, target):
    """
    Print the category counts and plot a stacked bar chart

    data: dataframe
    predictor: independent variable
    target: target variable
    """
    count = data[predictor].nunique()
    sorter = data[target].value_counts().index[-1]
    tab1 = pd.crosstab(data[predictor], data[target], margins=True).sort_values(
        by=sorter, ascending=False
    )
    print(tab1)
    print("-" * 120)
    tab = pd.crosstab(data[predictor], data[target], normalize="index").sort_values(
        by=sorter, ascending=False
    )
    tab.plot(kind="bar", stacked=True, figsize=(count + 1, 5))
    plt.legend(
        loc="lower  left", frameon=False,
    )
    plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
    plt.show()

# %%
# Box plot for Income observation
histogram_boxplot(df, "Income")

# %% [markdown]
# **Insights**: The income distribution is slightly right-skewed, with most customers earning between 30,000 and 80,000. A few outliers earn significantly more, as shown by the point on the far right of the box plot.

# %%
df[df["Income"] > 100000]
# Out:
#          Id  Year_Birth   Education Marital_Status    Income Kidhome Teenhome  \
# 210    4619        1945         PhD         Single  113734.0       0        0
# 325    4931        1977  Graduation        Married  157146.0       0        0
# 832    4611        1970  Graduation        Married  105471.0       0        0
# 1925  11181        1949         PhD        Married  156924.0       0        0
#
#      Dt_Customer Recency MntWines  ... MntGoldProds NumDealsPurchases  \
# 210    5/28/2014       9        6  ...            3                 0
# 325    4/29/2013      13        1  ...            1                 0
# 832    1/21/2013      36     1009  ...          207                 0
# 1925   8/29/2013      85        2  ...            1                 0
#
#      NumWebPurchases NumCatalogPurchases NumStorePurchases NumWebVisitsMonth  \
# 210               27                   0                 0                 1
# ...

# %%
# observations on MntMeatProducts
histogram_boxplot(df, "MntMeatProducts")

# %% [markdown]
# **Insights**: Most customers spend a small amount on meat products, with spending concentrated below 200. The distribution is heavily right-skewed, and there are many outliers where a few customers spend significantly more than the average.

# %%
# observations on NumWebVisitsMonth
histogram_boxplot(df, "NumWebVisitsMonth")

# %% [markdown]
# **Insights**: Most customers visit the website around 5 to 7 times per month. The distribution is slightly right-skewed, with a few outliers showing very high visit counts, suggesting some users are highly engaged online.

# %%
df[df["NumCatalogPurchases"] > 10]
# Out:
#          Id  Year_Birth   Education Marital_Status    Income Kidhome Teenhome  \
# 292    2324        1972  Graduation        Married   77044.0       0        1
# 325    4931        1977  Graduation        Married  157146.0       0        0
# 399    5718        1950  Graduation        Married   80763.0       0        0
# 661    4299        1960  Graduation        Married   70971.0       0        1
# 678   10524        1963      Master       Divorced   49476.0       0        1
# 911    6246        1953  Graduation         Single   73892.0       0        0
# 1368   2109        1990  Graduation         Single   96843.0       0        0
# 1404   1763        1988  Graduation        Married   87679.0       0        0
# 1489   9058        1955  Graduation          Widow   79800.0       0        0
# 1687   9292        1952  Graduation        Married   81795.0       0        0
# 2026   4964        1958         PhD        Married   74250.0       0        0
# ...

# %%
cols = [
    "MntWines",
    "MntGoldProds",
    "MntMeatProducts",
    "MntFruits",
    "MntFishProducts",
    "MntSweetProducts",
]

plt.figure(figsize=(12, 10))

for i, variable in enumerate(cols):
    plt.subplot(3, 2, i + 1)
    sns.boxplot(x="Response", y=variable, data=df,hue='Response', palette="Set2",legend=False)
    plt.title(f'{variable} vs Response')
    plt.xlabel("Response (0 = No, 1 = Yes)")
    plt.ylabel("Amount Spent")
    plt.tight_layout()

plt.suptitle("Product Spending by Campaign Response", fontsize=16, y=1.02)
plt.show()

# %%
# Filter out rows with missing or non-numeric values in either column
df_clean = df[["Income", "Total_Amount_Spent"]].dropna()

# Ensure both columns are numeric
df_clean = df_clean.astype({"Income": "float", "Total_Amount_Spent": "float"})

# Now plot
plt.figure(figsize=(8, 4))
sns.regplot(x="Income", y="Total_Amount_Spent", data=df_clean)
plt.title("Relationship Between Income and Total Amount Spent")
plt.xlabel("Income")
plt.ylabel("Total Amount Spent")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 3 - Probability Distributions 🎲
#
# - **Identify variables that could follow specific probability distributions (e.g., Binomial, Normal). Calculate probabilities and expected values based on these distributions.**

# %%
# Convert all columns that can be safely converted
df = df.apply(pd.to_numeric, errors='ignore')
# Out:
# <ipython-input-101-0a8a81ee2589>:2: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors='ignore')

# %%
from scipy.stats import shapiro, binom, norm
import pandas as pd

# Load data
# Visual Inspection
# Example: Plot histograms
df['Age'].hist(bins=20)
df['Income'].hist(bins=20)

# Descriptive Statistics
print(df[['Age', 'Income']].describe())

# Statistical Tests
# Shapiro-Wilk Test for Normality
stat_age, p_age = shapiro(df['Age'])
stat_income, p_income = shapiro(df['Income'])

# Binomial Test (if applicable)
# Example: if 'Age' could represent success/failure counts
n_age = len(df['Age'])
p_success_age = 0.5  # Adjust as needed
p_binom_age = sum(df['Age']) / (n_age * p_success_age)

# Calculations for Normal Distribution
mean_age = df['Age'].mean()
std_dev_age = df['Age'].std()

prob_less_than_40_age = norm.cdf(40, mean_age, std_dev_age)
expected_value_age = norm.mean(mean_age, std_dev_age)

# Calculations for Binomial Distribution (if applicable)
# Example: Calculate probabilities for 'Age' as a Binomial distribution
prob_success_3_age = binom.pmf(3, n_age, p_success_age)
prob_less_than_5_age = binom.cdf(4, n_age, p_success_age)

# Print results
print(f"Shapiro-Wilk test for 'Age': Statistics={stat_age}, p-value={p_age}")
print(f"Shapiro-Wilk test for 'Income': Statistics={stat_income}, p-value={p_income}")
print(f"Probability of 'Age' less than 40: {prob_less_than_40_age}")
print(f"Expected value (mean) for 'Age': {expected_value_age}")
# Out:
#              Age         Income
# count     1323.0    1323.000000
# mean   27.257748   51431.164979
# std    11.930114   20863.608954
# min          0.0    1730.000000
# 25%         19.0   35686.000000
# 50%         26.0   50664.000000
# 75%         37.0   68118.000000
# max         97.0  157146.000000
# Shapiro-Wilk test for 'Age': Statistics=0.9775251265278732, p-value=1.6839483391801312e-13
# Shapiro-Wilk test for 'Income': Statistics=0.981002828024095, p-value=3.496039031307955e-12
# Probability of 'Age' less than 40: 0.8572565860096086
# Expected value (mean) for 'Age': 27.25774754346183

# %%
# Example: Plot histograms
df['MntWines'].hist(bins=20)
df['MntFruits'].hist(bins=20)
df['MntMeatProducts'].hist(bins=20)
df['MntFishProducts'].hist(bins=20)

# Descriptive Statistics
print(df[['MntWines', 'MntFruits','MntMeatProducts','MntFishProducts']].describe())

# Statistical Tests
# Shapiro-Wilk Test for Normality
stat_mw, p_mw = shapiro(df['MntWines'])
stat_mf, p_mf = shapiro(df['MntFruits'])
stat_mm, p_mm = shapiro(df['MntMeatProducts'])
stat_mfo, p_mfo = shapiro(df['MntFishProducts'])

# Binomial Test (if applicable)
# Example: if 'MntWines' could represent success/failure counts
n_MntWines = len(df['MntWines'])
p_success_MntWines = 0.5  # Adjust as needed
p_binom_MntWines = sum(df['MntWines']) / (n_MntWines * p_success_MntWines)

# Calculations for Normal Distribution
mean_MntWines = df['MntWines'].mean()
std_dev_MntWines = df['MntWines'].std()

prob_less_than_40_MntWines = norm.cdf(40, mean_MntWines, std_dev_MntWines)
expected_value_MntWines = norm.mean(mean_MntWines, std_dev_MntWines)

# Calculations for Binomial Distribution (if applicable)
# Example: Calculate probabilities for 'Age' as a Binomial distribution
prob_success_3_MntWines = binom.pmf(3, n_MntWines, p_success_MntWines)
prob_less_than_5_MntWines = binom.cdf(4, n_MntWines, p_success_MntWines)
# Out:
#           MntWines    MntFruits  MntMeatProducts  MntFishProducts
# count  1323.000000  1323.000000      1323.000000      1323.000000
# mean    302.186697    25.237339       162.296296        36.507937
# std     338.423001    38.595947       219.244045        54.440217
# min       0.000000     0.000000         0.000000         0.000000
# 25%      23.000000     1.000000        15.000000         2.000000
# 50%     171.000000     7.000000        66.000000        11.000000
# 75%     494.500000    31.000000       217.000000        46.000000
# max    1492.000000   197.000000      1725.000000       253.000000

# %% [markdown]
# ## Task 4: Insights and Customer Segmentation 📈
#
# - **Explore relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %%
# Compute Pearson correlation coefficients with key variables age and income
correlation_matrix = df[['Age', 'Income']].corr()

# Print correlation matrix
print(correlation_matrix)
# Out:
#              Age    Income
# Age     1.000000  0.223732
# Income  0.223732  1.000000

# %%
df1 = df.copy()

# %%
# Dropping birth year and Dt_Customer columns
df1.drop(
    columns=[
        "Year_Birth",
        "Dt_Customer",

        "Total_Amount_Spent",
    ],
    inplace=True,
)

# %%
# Separating target variable and other variables

X = df1.drop(columns="Response")
X = pd.get_dummies(X)
Y = df1["Response"]

# %%
# To get different metric scores, and split data
from sklearn import metrics
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.metrics import (f1_score,
    accuracy_score,
    recall_score,
    precision_score,
    confusion_matrix,
    roc_auc_score
)
# Splitting data into training, validation and test set:
# first we split data into 2 parts, say temporary and test

X_temp, X_test, y_temp, y_test = train_test_split(X, Y, test_size=0.2, random_state=1, stratify=Y)

# then we split the temporary set into train and validation

X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.25, random_state=1, stratify=y_temp)

print(X_train.shape, X_val.shape, X_test.shape)
# Out:
# (793, 26) (265, 26) (265, 26)

# %%
# To be used for missing value imputation
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="median")

# %%
# Fit and transform the train data
X_train = pd.DataFrame(imputer.fit_transform(X_train), columns=X_train.columns)

# Transform the validation data
X_val = pd.DataFrame(imputer.transform(X_val), columns=X_train.columns)

# Transform the test data
X_test = pd.DataFrame(imputer.transform(X_test), columns=X_train.columns)

# %%
# Checking that no column has missing values in train or test sets
print(X_train.isna().sum())
print("-" * 30)
print(X_val.isna().sum())
print("-" * 30)
print(X_test.isna().sum())
# Out:
# Id                         0
# Income                     0
# Kidhome                    0
# Teenhome                   0
# Recency                    0
# MntWines                   0
# MntFruits                  0
# MntMeatProducts            0
# MntFishProducts            0
# MntSweetProducts           0
# MntGoldProds               0
# NumDealsPurchases          0
# NumWebPurchases            0
# NumCatalogPurchases        0
# NumStorePurchases          0
# NumWebVisitsMonth          0
# Complain                   0
# Age                        0
# Education_Basic            0
# Education_Graduation       0
# Education_Master           0
# Education_PhD              0
# Marital_Status_Divorced    0
# Marital_Status_Married     0
# Marital_Status_Single      0
# Marital_Status_Widow       0
# dtype: int64
# ------------------------------
# Id                         0
# Income                     0
# Kidhome                    0
# Teenhome                   0
# ...

# %%
scorer = metrics.make_scorer(metrics.recall_score)

# %%
# defining a function to compute different metrics to check performance of a classification model built using sklearn
def model_performance_classification_sklearn(model, predictors, target):
    """
    Function to compute different metrics to check classification model performance

    model: classifier
    predictors: independent variables
    target: dependent variable
    """

    # predicting using the independent variables
    pred = model.predict(predictors)

    acc = accuracy_score(target, pred)  # to compute Accuracy
    recall = recall_score(target, pred)  # to compute Recall
    precision = precision_score(target, pred)  # to compute Precision
    f1 = f1_score(target, pred)  # to compute F1-score

    # creating a dataframe of metrics
    df_perf = pd.DataFrame(
        {
            "Accuracy": acc,
            "Recall": recall,
            "Precision": precision,
            "F1": f1,
        },
        index=[0],
    )

    return df_perf

# %%
def confusion_matrix_sklearn(model, predictors, target):
    """
    To plot the confusion_matrix with percentages

    model: classifier
    predictors: independent variables
    target: dependent variable
    """
    y_pred = model.predict(predictors)
    cm = confusion_matrix(target, y_pred)
    labels = np.asarray(
        [
            ["{0:0.0f}".format(item) + "\n{0:.2%}".format(item / cm.flatten().sum())]
            for item in cm.flatten()
        ]
    ).reshape(2, 2)

    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=labels, fmt="")
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

# %%
# To help with model building
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (AdaBoostClassifier,GradientBoostingClassifier,RandomForestClassifier,
    BaggingClassifier)

models = []  # Empty list to store all the models

# Appending models into the list
models.append(("Bagging", BaggingClassifier(random_state=1)))
models.append(("Random forest", RandomForestClassifier(random_state=1)))
models.append(("GBM", GradientBoostingClassifier(random_state=1)))
models.append(("Adaboost", AdaBoostClassifier(random_state=1)))
models.append(("dtree", DecisionTreeClassifier(random_state=1)))

results1 = []  # Empty list to store all model's CV scores
names = []  # Empty list to store name of the models
print("\n" "Cross-Validation performance on training dataset:" "\n")

for name, model in models:
    kfold = StratifiedKFold(
        n_splits=5, shuffle=True, random_state=1
    )  # Setting number of splits equal to 5
    cv_result = cross_val_score(
        estimator=model, X=X_train, y=y_train, scoring = scorer,cv=kfold
    )
    results1.append(cv_result)
    names.append(name)
    print("{}: {}".format(name, cv_result.mean()))

print("\n" "Validation Performance:" "\n")

for name, model in models:
    model.fit(X_train, y_train)
    scores = recall_score(y_val, model.predict(X_val))
    print("{}: {}".format(name, scores))
# Out:
# Cross-Validation performance on training dataset:
#
# Bagging: 0.26666666666666666
# Random forest: 0.15833333333333333
# GBM: 0.325
# Adaboost: 0.25
# dtree: 0.31666666666666665
#
# Validation Performance:
#
# Bagging: 0.2
# Random forest: 0.225
# GBM: 0.225
# Adaboost: 0.225
# dtree: 0.325

# %%
fig = plt.figure(figsize=(10, 7))

fig.suptitle("Algorithm Comparison")
ax = fig.add_subplot(111)

plt.boxplot(results1)
ax.set_xticklabels(names)

plt.show()

# %%
# generate data
# n== number of trials,p== probability of each trial
n, p = 10, 0.6
data = np.random.binomial(n, p, 10000)

# plotting a histogram
ax = sns.distplot(data,
                  bins=20,
                  kde=False,
                  color='blue',
                  hist_kws={"linewidth": 15, 'alpha': 1})
ax.set(xlabel='Binomial Distribution', ylabel='Frequency')

plt.show()
# Out:
# <ipython-input-121-06720916e80c>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(data,

# %%
poisson_data = np.random.poisson(lam=5, size=1000)

# plotting a histogram
ax = sns.distplot(poisson_data,
                  kde=False,
                  color='brown')
ax.set(xlabel='Poisson Distribution', ylabel='Frequency')
plt.show()
# Out:
# <ipython-input-122-1a3cd7210db9>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(poisson_data,

# %%
def normal_dist(x, mean, sd):
      prob_density = (np.pi*sd) * np.exp(-0.5*((x-mean)/sd)**2)
      return prob_density

mean = 0
sd = 1
x = 1
result = normal_dist(x, mean, sd)
print(result)
# Out:
# 1.9054722647301798

# %%
from scipy.stats import norm
data = norm.rvs(10.0, 2.5, size=500)

# Fit a normal distribution to the data:
mu, std = norm.fit(data)

# Plot the histogram.
plt.hist(data, bins=25, density=True, alpha=0.6, color='m')

# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)

plt.show()

# %% [markdown]
# ## Task 5: Conclusion and Recommendations

# %% [markdown]
# **Insights**:
# We found clear groups of customers based on how they shop and their background.
#
# People with higher incomes tend to spend more on luxury products.
#
# Younger customers shop more often but usually spend less each time.
#
# There’s a link between age and how often people buy, meaning age can help predict shopping habits.
#
# These findings can help us create better marketing plans and keep customers coming back.
#
# **Recommendations**:
# Target high-income customers with ads and offers for premium products.
#
# Start a loyalty program for younger customers to encourage them to buy more over time.
#
# Improve the online shopping experience to match customer preferences and increase engagement.
#
# For deeper insights, we suggest using statistical tests and machine learning to find strong patterns and improve marketing strategies even more.
